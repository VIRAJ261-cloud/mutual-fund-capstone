# %%
import pandas as pd
import numpy as np
import os 
from sklearn.preprocessing import StandardScaler

# %%
# Before running this cell , make sure you run createFolder.py and you run this file in this dataCleaning folder, which is inside notebook folder
with open("dataFolder.txt",'r') as f:
    folder = f.read()

# %%
filePath = os.path.join(folder,"08_investor_transactions.csv")

# %%
df = pd.read_csv(filePath)

# %%
df.head()
# Out:
#   investor_id transaction_date  amfi_code transaction_type  amount_inr  \
# 0   INV003054       2024-01-01     119092              SIP        1834
# 1   INV002952       2024-01-01     148567       Redemption      392882
# 2   INV003420       2024-01-01     118636              SIP         912
# 3   INV003436       2024-01-01     118634              SIP        1102
# 4   INV004691       2024-01-01     119094          Lumpsum        8682
#
#          state       city city_tier age_group  gender  annual_income_lakh  \
# 0    Telangana  Hyderabad       T30       56+  Female                77.1
# 1       Punjab   Amritsar       B30     18-25    Male                 7.1
# 2      Haryana  Faridabad       B30     36-45    Male                47.2
# 3  Maharashtra     Mumbai       T30     36-45  Female                54.4
# 4        Delhi      Noida       T30     26-35    Male                14.5
#
#   payment_mode kyc_status
# 0          UPI   Verified
# 1       Cheque   Verified
# ...

# %%
df['transaction_type'].value_counts()
# Out:
# transaction_type
# SIP           19716
# Lumpsum        8095
# Redemption     4967
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# investor_id           0
# transaction_date      0
# amfi_code             0
# transaction_type      0
# amount_inr            0
# state                 0
# city                  0
# city_tier             0
# age_group             0
# gender                0
# annual_income_lakh    0
# payment_mode          0
# kyc_status            0
# dtype: int64

# %% [markdown]
# ## Standardize Transaction_type

# %%
df['transaction_type'].unique()
# Out:
# array(['SIP', 'Redemption', 'Lumpsum'], dtype=object)

# %% [markdown]
# ## Validate amount>0

# %%
df[df['amount_inr']<=0]
# Out:
# Empty DataFrame
# Columns: [investor_id, transaction_date, amfi_code, transaction_type, amount_inr, state, city, city_tier, age_group, gender, annual_income_lakh, payment_mode, kyc_status]
# Index: []

# %% [markdown]
# ## Fix dates format

# %%
df.dtypes
# Out:
# investor_id            object
# transaction_date       object
# amfi_code               int64
# transaction_type       object
# amount_inr              int64
# state                  object
# city                   object
# city_tier              object
# age_group              object
# gender                 object
# annual_income_lakh    float64
# payment_mode           object
# kyc_status             object
# dtype: object

# %%
df['transaction_date']
# Out:
# 0        2024-01-01
# 1        2024-01-01
# 2        2024-01-01
# 3        2024-01-01
# 4        2024-01-01
#             ...
# 32773    2025-05-30
# 32774    2025-05-30
# 32775    2025-05-30
# 32776    2025-05-30
# 32777    2025-05-30
# Name: transaction_date, Length: 32778, dtype: object

# %%
df['transaction_date'] = pd.to_datetime(df['transaction_date'])

# %%
df.dtypes
# Out:
# investor_id                   object
# transaction_date      datetime64[ns]
# amfi_code                      int64
# transaction_type              object
# amount_inr                     int64
# state                         object
# city                          object
# city_tier                     object
# age_group                     object
# gender                        object
# annual_income_lakh           float64
# payment_mode                  object
# kyc_status                    object
# dtype: object

# %% [markdown]
# ## check KYC status enum values

# %%
df['kyc_status'].unique()
# Out:
# array(['Verified', 'Pending'], dtype=object)

# %%
df['kyc_status'].value_counts()
# Out:
# kyc_status
# Verified    30146
# Pending      2632
# Name: count, dtype: int64

# %%
df['kyc_status'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.head()
# Out:
#   investor_id transaction_date  amfi_code transaction_type  amount_inr  \
# 0   INV003054       2024-01-01     119092              SIP        1834
# 1   INV002952       2024-01-01     148567       Redemption      392882
# 2   INV003420       2024-01-01     118636              SIP         912
# 3   INV003436       2024-01-01     118634              SIP        1102
# 4   INV004691       2024-01-01     119094          Lumpsum        8682
#
#          state       city city_tier age_group  gender  annual_income_lakh  \
# 0    Telangana  Hyderabad       T30       56+  Female                77.1
# 1       Punjab   Amritsar       B30     18-25    Male                 7.1
# 2      Haryana  Faridabad       B30     36-45    Male                47.2
# 3  Maharashtra     Mumbai       T30     36-45  Female                54.4
# 4        Delhi      Noida       T30     26-35    Male                14.5
#
#   payment_mode kyc_status
# 0          UPI   Verified
# 1       Cheque   Verified
# ...

# %%
fol = os.path.dirname(folder)
savePath = os.path.join(fol,"processed")
df.to_csv(os.path.join(savePath,"c_investor_transaction.csv"),index=False)
