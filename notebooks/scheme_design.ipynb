# %%
import pandas as pd 
import numpy as np
import os

# %%
folder = os.path.join(os.path.dirname(os.getcwd()),"data","raw")
files = os.listdir(folder)

# %%
files = files[:10]

# %%
for file in files:
    filePath = os.path.join(folder,file)
    df = pd.read_csv(filePath)
    print(f"\033[1mFile Name - {file}\033[0m")
    print(f"\n{df.isnull().sum()}\n{df.shape}\n")
    
    for i in df.columns:
        print(f"{i} = {df[i].dtype}")
    print("="*50)
# Out:
# File Name - 01_fund_master.csv
#
# amfi_code             0
# fund_house            0
# scheme_name           0
# category              0
# sub_category          0
# plan                  0
# launch_date           0
# benchmark             0
# expense_ratio_pct     0
# exit_load_pct         0
# min_sip_amount        0
# min_lumpsum_amount    0
# fund_manager          0
# risk_category         0
# sebi_category_code    0
# dtype: int64
# (40, 15)
#
# amfi_code = int64
# fund_house = object
# scheme_name = object
# category = object
# sub_category = object
# plan = object
# launch_date = object
# benchmark = object
# expense_ratio_pct = float64
# exit_load_pct = float64
# min_sip_amount = int64
# min_lumpsum_amount = int64
# fund_manager = object
# risk_category = object
# sebi_category_code = object
# ...
# File Name - 02_nav_history.csv
#
# amfi_code    0
# date         0
# nav          0
# dtype: int64
# (46000, 3)
#
# amfi_code = int64
# date = object
# nav = float64
# ...

# %%
# from the above file i can see that , the 04_monthly_sip_inflows.csv have some null values and that too 1/4 of the data , so i must fill it

# %%
df = pd.read_csv(os.path.join(folder,"04_monthly_sip_inflows.csv"))

# %%
df.head()
# Out:
#      month  sip_inflow_crore  active_sip_accounts_crore  \
# 0  2022-01             11517                       4.91
# 1  2022-02             11438                       4.93
# 2  2022-03             12328                       5.09
# 3  2022-04             11863                       5.48
# 4  2022-05             12286                       5.55
#
#    new_sip_accounts_lakh  sip_aum_lakh_crore  yoy_growth_pct
# 0                   9.10                4.80             NaN
# 1                   8.20                4.85             NaN
# 2                  10.50                5.01             NaN
# 3                   9.52                5.12             NaN
# 4                   8.10                5.15             NaN
